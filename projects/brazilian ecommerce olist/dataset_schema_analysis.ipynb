# %%
import os
import sys
import numpy as np
import pandas as pd
from sqlalchemy import create_engine, inspect
dataset_path = os.path.join('..', '..', 'datasets', 'brazilian e-commerce dataset')
sys.path.append(os.path.join('..', '..', 'packages'))
from alexandria.secrets import DATABASES_INFO

# %%
engine = create_engine(DATABASES_INFO['br_ecommerce'], echo_pool=True)
connection = engine.connect()
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['customers',
#  'geolocation',
#  'orders',
#  'order_items',
#  'order_payments',
#  'order_reviews',
#  'sellers',
#  'category_translation',
#  'products']

# %%
df = pd.read_sql_query('SELECT * FROM orders LEFT JOIN order_payments ON orders.id = order_payments.order_id', connection)
df
# Out:
#                                           id  \
# 0       a9810da8-2917-af2d-9aef-d1278f1dcfa0
# 1       3d7239c3-94a2-12fa-ae12-2962df514ac7
# 2       616105c9-352a-9668-c383-03ad44e056cd
# 3       cf95215a-722f-3ebf-29e6-bbab87a29e61
# 4       76921417-6682-788a-9280-1d8907fa1b40
# ...                                      ...
# 103882  f593228a-7a25-e963-3ff7-8a4ce0d0d4cc
# 103883  387c2c33-e495-538e-9487-8a500bf8e6d5
# 103884  0872d0fa-afe0-cb56-e6f2-c594cca1522c
# 103885  7159096c-5aa9-be77-f7f0-c26c01ee9793
# 103886  7b905861-d7c8-2589-1d63-47454ea7863f
#
#                                  customer_id     status      purchase_times  \
# 0       f2c7fc58-a9de-8108-2871-5166c672f10a  delivered 2018-06-26 11:01:38
# 1       4d7a9b8b-ba45-9dce-09d1-b8fa637a0cba  delivered 2017-06-05 10:45:54
# 2       8c0b2ef9-efb4-3af9-2d5c-0afff70d33d9  delivered 2018-06-11 16:19:00
# 3       e2a8d072-0163-9004-b090-670ce5efe355  delivered 2017-08-25 17:14:15
# ...

# %%
df = pd.read_sql_query('SELECT * FROM orders', connection)
df
